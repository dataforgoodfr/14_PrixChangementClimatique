# %%
import pandas as pd
import duckdb

# %%
con = duckdb.connect('../../dev.duckdb')

# %%
df_ccr = con.sql("SELECT * from ccr_details").df()
df_catnat = con.sql("SELECT * from catnat_gaspar").df()

# %%
df_ccr.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243032 entries, 0 to 243031
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   code_geo              243032 non-null  str
#  1   nom_commune           243032 non-null  str
#  2   date_debut_evenement  243032 non-null  datetime64[us]
#  3   date_fin_evenement    243032 non-null  datetime64[us]
#  4   date_arrete           243032 non-null  datetime64[us]
#  5   date_parution_jo      243032 non-null  datetime64[us]
#  6   nom_peril             243032 non-null  str
#  7   franchise             243032 non-null  str
#  8   libelle_avis          243032 non-null  str
#  9   code_arrete           243032 non-null  int64
# dtypes: datetime64[us](4), int64(1), str(5)
# memory usage: 31.7 MB

# %%
df_ccr[df_ccr["date_debut_evenement"] == df_ccr["date_fin_evenement"]]
# Out:
#        code_geo                     nom_commune date_debut_evenement  \
# 0         07005                 ALBA LA ROMAINE           2025-11-16
# 2         07181                       LE POUZIN           2025-11-16
# 4         07219                   SAINT BAUZILE           2025-11-16
# 7         07270        SAINT MARTIN SUR LAVEZON           2025-11-16
# 8         07298  SAINT SYMPHORIEN SOUS CHOMERAC           2025-11-16
# ...         ...                             ...                  ...
# 243027    69009                            ANSE           1982-08-16
# 243028    69052               CHAZAY D AZERGUES           1982-08-16
# 243029    69122                         LUCENAY           1982-08-16
# 243030    69140                         MORANCE           1982-08-16
# 243031    69163                       QUINCIEUX           1982-08-16
#
#        date_fin_evenement date_arrete date_parution_jo  \
# 0              2025-11-16  2026-01-19       2026-01-24
# 2              2025-11-16  2026-01-19       2026-01-24
# 4              2025-11-16  2026-01-19       2026-01-24
# 7              2025-11-16  2026-01-19       2026-01-24
# 8              2025-11-16  2026-01-19       2026-01-24
# ...                   ...         ...              ...
# 243027         1982-08-16  1982-09-21       1982-09-30
# 243028         1982-08-16  1982-09-21       1982-09-30
# 243029         1982-08-16  1982-09-21       1982-09-30
# 243030         1982-08-16  1982-09-21       1982-09-30
# 243031         1982-08-16  1982-09-21       1982-09-30
#
#                                 nom_peril franchise  libelle_avis  code_arrete
# 0       Inondations et/ou Coulées de Boue         -  Non reconnue          904
# 2       Inondations et/ou Coulées de Boue         -  Non reconnue          904
# 4       Inondations et/ou Coulées de Boue    Simple      Reconnue          904
# 7       Inondations et/ou Coulées de Boue    Simple      Reconnue          904
# 8       Inondations et/ou Coulées de Boue         -  Non reconnue          904
# ...                                   ...       ...           ...          ...
# 243027  Inondations et/ou Coulées de Boue    Simple      Reconnue           48
# 243028  Inondations et/ou Coulées de Boue    Simple      Reconnue           48
# 243029  Inondations et/ou Coulées de Boue    Simple      Reconnue           48
# 243030  Inondations et/ou Coulées de Boue    Simple      Reconnue           48
# 243031  Inondations et/ou Coulées de Boue    Simple      Reconnue           48
#
# [37928 rows x 10 columns]

# %%
df_ccr["date_debut_evenement"].describe()
# Out:
# count                        243032
# mean     2003-05-18 15:01:56.962375
# min             1982-08-15 00:00:00
# 25%             1990-06-26 00:00:00
# 50%             2003-07-01 00:00:00
# 75%             2017-01-01 00:00:00
# max             2025-12-19 00:00:00
# Name: date_debut_evenement, dtype: object

# %%
df_catnat.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 260799 entries, 0 to 260798
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   cod_nat_catnat  260799 non-null  str
#  1   cod_commune     260799 non-null  str
#  2   lib_commune     260799 non-null  str
#  3   num_risque_jo   260799 non-null  str
#  4   lib_risque_jo   260799 non-null  str
#  5   dat_deb         260799 non-null  datetime64[us]
#  6   dat_fin         260799 non-null  datetime64[us]
#  7   dat_pub_arrete  260799 non-null  datetime64[us]
#  8   dat_pub_jo      260799 non-null  datetime64[us]
#  9   dat_maj         260799 non-null  datetime64[us]
# dtypes: datetime64[us](5), str(5)
# memory usage: 34.3 MB

# %%
df_catnat["dat_deb"].describe()
# Out:
# count                        260799
# mean     1999-10-27 00:33:25.296032
# min             1982-08-15 00:00:00
# 25%             1989-05-01 00:00:00
# 50%             1999-12-25 00:00:00
# 75%             2009-01-24 00:00:00
# max             2025-09-20 00:00:00
# Name: dat_deb, dtype: object
