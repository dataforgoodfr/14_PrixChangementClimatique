# %%
import pandas as pd

# %%
df_ccr_details = pd.read_csv('../../pipeline_inputs/ccr_details.csv')
df_ccr_details.head(5)
# Out:
#   codeInsee       nomCommune dateDebutEvenement dateFinEvenement  dateArrete  \
# 0     07005  ALBA LA ROMAINE         16-11-2025       16-11-2025  19-01-2026
# 1     07022             BAIX         16-11-2025       17-11-2025  19-01-2026
# 2     07181        LE POUZIN         16-11-2025       16-11-2025  19-01-2026
# 3     07198           ROMPON         15-11-2025       16-11-2025  19-01-2026
# 4     07219    SAINT BAUZILE         16-11-2025       16-11-2025  19-01-2026
#
#   dateParutionJO                           nomPeril franchise   libelleAvis  \
# 0     24-01-2026  Inondations et/ou Coulées de Boue         -  Non reconnue
# 1     24-01-2026  Inondations et/ou Coulées de Boue    Simple      Reconnue
# 2     24-01-2026  Inondations et/ou Coulées de Boue         -  Non reconnue
# 3     24-01-2026  Inondations et/ou Coulées de Boue         -  Non reconnue
# 4     24-01-2026  Inondations et/ou Coulées de Boue    Simple      Reconnue
#
#    code_arrete
# 0          904
# ...

# %%
df_ccr_details.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 243032 entries, 0 to 243031
# Data columns (total 10 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   codeInsee           243032 non-null  str
#  1   nomCommune          243032 non-null  str
#  2   dateDebutEvenement  243032 non-null  str
#  3   dateFinEvenement    243032 non-null  str
#  4   dateArrete          243032 non-null  str
#  5   dateParutionJO      243032 non-null  str
#  6   nomPeril            243032 non-null  str
#  7   franchise           243032 non-null  str
#  8   libelleAvis         243032 non-null  str
#  9   code_arrete         243032 non-null  int64
# dtypes: int64(1), str(9)
# memory usage: 41.0 MB

# %%
df_ccr_details["franchise"].value_counts()
# Out:
# franchise
# Simple        191552
# -              44893
# Doublée         4921
# Triplée         1326
# Quadruplée       340
# Name: count, dtype: int64
