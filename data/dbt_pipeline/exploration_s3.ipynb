# %%
import duckdb

dev = duckdb.connect("dev.duckdb")
odis = duckdb.connect("odis.duckdb")

# %%
dev.execute("SHOW TABLES").fetchall()
# Out:
# [('azi_gaspar',),
#  ('budget_communes',),
#  ('catnat_gaspar',),
#  ('ccr_details',),
#  ('ccr_main_page',),
#  ('dicrim_gaspar',),
#  ('insee_filosofi_2021',),
#  ('pprm_gaspar',),
#  ('pprn_gaspar',),
#  ('pprt_gaspar',),
#  ('res2_insee',),
#  ('risq_gaspar',),
#  ('taux_chomage_communes',),
#  ('test',),
#  ('tim_gaspar',)]

# %%
df = dev.execute("SELECT * FROM ccr_details").df()
df.head()
# Out:
#   Code_FAP341                                    Intitulé_FAP341 Code_FAP228  \
# 0       A0X40                                       Agriculteurs       A0X40
# 1      A0X41a                     Eleveurs de bovins ou d'équins       A0X41
# 2      A0X41b  Eleveurs d'insectes, d'animaux sauvages ou de ...       A0X41
# 3      A0X41c                    Eleveurs de lapins et volailles       A0X41
# 4      A0X41d                     Eleveurs d'ovins ou de caprins       A0X41
#
#   Intitulé_FAP228 Code_FAP86  \
# 0    Agriculteurs        A0X
# 1        Eleveurs        A0X
# 2        Eleveurs        A0X
# 3        Eleveurs        A0X
# 4        Eleveurs        A0X
#
#                                      Intitulé_FAP86 Code_FAP22  \
# 0  Agriculteurs, éleveurs, sylviculteurs, bûcherons          A
# 1  Agriculteurs, éleveurs, sylviculteurs, bûcherons          A
# 2  Agriculteurs, éleveurs, sylviculteurs, bûcherons          A
# 3  Agriculteurs, éleveurs, sylviculteurs, bûcherons          A
# ...
